# %%
import os
import cv2
import glob
import random
import pywt
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as Kback
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Reshape, Dropout, Concatenate, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.layers import Input, Concatenate, Flatten, Dense, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Load dataset**

# %%
Train = []
Valid = []
Test = []

for x in os.walk('/kaggle/input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/train'):
    for y in glob.glob(os.path.join(x[0], '*.jpg')):
        Train.append(y)
        
for x in os.walk('/kaggle/input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/valid'):
    for y in glob.glob(os.path.join(x[0], '*.jpg')):
        Valid.append(y)

for x in os.walk('/kaggle/input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test'):
    for y in glob.glob(os.path.join(x[0], '*.jpg')):
        Test.append(y)
        
print(len(Train),len(Valid), len(Test))
# Out:
# 100000 20000 20000

# %%
# Divided into train and test sets
X_train, Y_test = train_test_split(allImages, test_size = 0.2, random_state=35)

# Divided into train and validation sets
X_train, Y_val = train_test_split(X_train, test_size = 0.2, random_state=15)
print(len(X_train),len(Y_test),len(Y_val))

# %% [markdown]
# **Xception Model**

# %%
def build_model(input_shape):
    # Shared input layer
    input_tensor = Input(shape=input_shape)

    xception_model = Xception(weights='imagenet', include_top=False, input_tensor=input_tensor)
    out = xception_model.output
    xception_out = tf.keras.layers.GlobalAveragePooling2D()(out)
    
    x1 = tf.keras.layers.Conv2D(8, (3, 3), padding='same', activation = 'relu')(input_tensor)
    x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), padding='same')(x1)
    x2 = tf.keras.layers.Conv2D(8, (5, 5), padding='same', activation = 'relu')(x1)
    x2 = tf.keras.layers.BatchNormalization()(x2)
    x2 = tf.keras.layers.MaxPooling2D(pool_size=(4, 4), padding='same')(x2)
    #y = tf.keras.layers.Flatten()(x4)
    y = tf.keras.layers.GlobalAveragePooling2D()(x2)
    # Concatenate the output of Xception and the last convolutional layer
    #concatenated = Concatenate()([xception_out, y])

    # MLP for binary classification
    mlp = Dense(1024, activation='relu')(y)
    mlp = tf.keras.layers.Dropout(0.5)(mlp)
    mlp = BatchNormalization()(mlp)
    mlp = Dense(512, activation='relu')(mlp)
    mlp = tf.keras.layers.Dropout(0.5)(mlp)
    mlp = BatchNormalization()(mlp)
    mlp_output = Dense(2, activation='softmax')(mlp)

    # Create the final model'''
    model = Model(inputs=input_tensor, outputs = mlp_output)
    return model

# %%
input_shape = (299, 299, 3)
model = build_model(input_shape)
plot_model(model, show_shapes=True, to_file='model1.png')

# %%
def build_efficientnet_b0_model(input_shape):
    # Load pre-trained EfficientNet-B0 model
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the base model layers
    base_model.trainable = False

    # Create a new model on top
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    output = Dense(2, activation='softmax')(x)

    return output

# %%
input_shape = (299, 299, 3)
model2 = build_efficientnet_b0_model(input_shape)
#plot_model(model, show_shapes=True, to_file='model1.png')

# %% [markdown]
# **Convolution Model**

# %%
    model2 = Sequential()
    
    model2.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (299, 299, 3)))
    model2.add(MaxPooling2D((2,2)))
    
    model2.add(Conv2D(32, (3,3), activation = 'relu'))
    model2.add(MaxPooling2D((2,2)))
    
    model2.add(Conv2D(32, (3,3), activation = 'relu'))
    model2.add(MaxPooling2D((2,2)))

    model2.add(Flatten())
    model2.add(Dense(64, activation = 'relu'))
    model2.add(Dense(64, activation = 'relu'))
    
    model2.add(Dense(2, activation = 'softmax'))
    
    #plot_model(model2, to_file='model2.png')

# %% [markdown]
# **Concatenation**

# %%
x = Concatenate()([model1.output,model2.output])
x = Dense(units=128, activation='relu')(x) 
x = Dense(units=64, activation='relu')(x) 
output = Dense(2, activation='softmax', name='output')(x)
model5 = Model(inputs=[model1.input, model2.input], outputs=output)
#plot_model(net_model, to_file='model.png')

# %% [markdown]
# **Reading Images**

# %%
def color_to_luminance_and_wavelet(image_path):
    # Read the color image
    original_image = cv2.imread(image_path)

    # Convert the color image to luminance (grayscale)
    luminance_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Resize the luminance image to ensure its size is compatible with wavelet transform
    rows, cols = luminance_image.shape
    if rows % 2 != 0:
        rows -= 1
    if cols % 2 != 0:
        cols -= 1
    luminance_image = cv2.resize(luminance_image, (cols, rows))

    # Apply Haar wavelet transform
    coeffs = pywt.dwt2(luminance_image, 'haar')

    # Extract LL (approximation) coefficients
    LL, (_, _, _) = coeffs

    # Resize LL coefficients to match the size of the luminance image
    LL = cv2.resize(LL, (cols, rows))

    # Subtract LL coefficients from the luminance image to get high-frequency residual
    high_frequency_residual = luminance_image.astype(int) - LL.astype(int)
    
    uint8_HFR = high_frequency_residual.astype(np.uint8)
    
    # Convert BGR image to HSV
    hsv_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)

    # Extract individual components
    h, _, _ = cv2.split(hsv_image)
    
    h = cv2.resize(h, (cols, rows))
        
    #print(original_image.shape, h.shape, luminance_image.shape, uint8_HFR.shape)
    #print('HFR', high_frequency_residual.shape)
    mergedImage = cv2.merge([h, luminance_image, uint8_HFR])
    
    return mergedImage

# %%
def image_generator(files, batch_size, resize=None):
    while True:
        batch_paths  = np.random.choice(a = files, size = batch_size)
        batch_x = []
        batch_y = [] 
          
        for input_path in batch_paths:
            input = get_input(input_path)
            output = get_output(input_path)
            if resize is not None:
                input = cv2.resize(input, resize)
            batch_x.append(input)
            batch_y.append(output)

        batch_x = np.array(batch_x)
        batch_y = np.array(batch_y)
        yield batch_x, batch_y

# %%
def get_input(path):
    #img = cv2.imread(path)
    img = color_to_luminance_and_wavelet(path)
    input = cv2.resize(img, (299, 299))
    return(input)
 
def get_output(path):
    #Considered fake = 1 and real = 0
    labaF = [1,0]
    labaT = [0,1]
    folder_path = os.path.dirname(path)
    label = os.path.basename(folder_path)  # Extracting folder name instead of file name
    if 'fake' == label:
        return labaF
    else:
        return labaT

# %% [markdown]
# **Matrices**

# %%
def f1_score(y_true, y_pred):
    y_true = Kback.cast(y_true, 'float32') 
    true_positives = Kback.sum(Kback.round(Kback.clip(y_true * y_pred, 0, 1)))
    possible_positives = Kback.sum(Kback.round(Kback.clip(y_true, 0, 1)))
    predicted_positives = Kback.sum(Kback.round(Kback.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + Kback.epsilon())
    recall = true_positives / (possible_positives + Kback.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+Kback.epsilon())
    return f1_val

METRICS = [
      "accuracy",
      tf.metrics.Precision(name='precision'),
      tf.metrics.Recall(name='recall'),
      tf.metrics.AUC(name='auc'),
      f1_score
]

# %%
#model = build_model((299,299,3))  
# Compile the model
optimizer = tf.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, clipnorm=1.0)
model.compile(loss=["categorical_crossentropy"], metrics=METRICS, optimizer = optimizer)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
    )

#EarlyStopping_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

history = model.fit(image_generator(Train, batch_size = 32),
                    epochs = 100,
                    steps_per_epoch = 40,
                    validation_data = image_generator(Valid, batch_size = 32),
                    validation_steps = 15,
                    verbose = 1,
                    callbacks=[model_checkpoint_callback],
                    shuffle = True)
# Out:
# Epoch 1/100
# 2024-04-04 04:51:33.624848: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.14422, expected 3.389
# 2024-04-04 04:51:33.624915: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.90007, expected 5.14485
# 2024-04-04 04:51:33.624925: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.30012, expected 5.5449
# 2024-04-04 04:51:33.624933: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.23722, expected 5.482
# 2024-04-04 04:51:33.624940: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.08366, expected 5.32844
# 2024-04-04 04:51:33.624948: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.04657, expected 5.29135
# 2024-04-04 04:51:33.624956: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.75857, expected 5.00335
# 2024-04-04 04:51:33.624963: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.00133, expected 4.24611
# 2024-04-04 04:51:33.624971: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.91496, expected 4.15974
# 2024-04-04 04:51:33.624983: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.14032, expected 4.3851
# 2024-04-04 04:51:33.635054: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 04:51:33.635096: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 04:51:33.635105: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 04:51:33.635113: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 04:51:33.635120: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 04:51:33.635136: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 04:51:34.019362: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.14422, expected 3.389
# 2024-04-04 04:51:34.019431: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.90007, expected 5.14485
# 2024-04-04 04:51:34.019441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.30012, expected 5.5449
# 2024-04-04 04:51:34.019449: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.23722, expected 5.482
# 2024-04-04 04:51:34.019457: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.08366, expected 5.32844
# 2024-04-04 04:51:34.019465: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.04657, expected 5.29135
# 2024-04-04 04:51:34.019472: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.75857, expected 5.00335
# 2024-04-04 04:51:34.019480: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.00133, expected 4.24611
# 2024-04-04 04:51:34.019488: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.91496, expected 4.15974
# 2024-04-04 04:51:34.019495: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.14032, expected 4.3851
# 2024-04-04 04:51:34.029560: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 04:51:34.029601: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 04:51:34.029610: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 04:51:34.029617: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 04:51:34.029624: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 04:51:34.029641: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712206343.289345     104 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.5193 - auc: 0.5261 - f1_score: 0.5193 - loss: 1.0040 - precision: 0.5193 - recall: 0.5193
# Epoch 1: val_accuracy improved from -inf to 0.60625, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 129s 705ms/step - accuracy: 0.5201 - auc: 0.5272 - f1_score: 0.5201 - loss: 1.0027 - precision: 0.5201 - recall: 0.5201 - val_accuracy: 0.6062 - val_auc: 0.6215 - val_f1_score: 0.6062 - val_loss: 0.6751 - val_precision: 0.6062 - val_recall: 0.6062
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.6147 - auc: 0.6622 - f1_score: 0.6147 - loss: 0.8349 - precision: 0.6147 - recall: 0.6147
# Epoch 2: val_accuracy improved from 0.60625 to 0.61250, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 23s 574ms/step - accuracy: 0.6154 - auc: 0.6629 - f1_score: 0.6154 - loss: 0.8341 - precision: 0.6154 - recall: 0.6154 - val_accuracy: 0.6125 - val_auc: 0.6641 - val_f1_score: 0.6125 - val_loss: 0.6538 - val_precision: 0.6125 - val_recall: 0.6125
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.6255 - auc: 0.6878 - f1_score: 0.6255 - loss: 0.8240 - precision: 0.6255 - recall: 0.6255
# Epoch 3: val_accuracy improved from 0.61250 to 0.62083, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 562ms/step - accuracy: 0.6262 - auc: 0.6886 - f1_score: 0.6262 - loss: 0.8225 - precision: 0.6262 - recall: 0.6262 - val_accuracy: 0.6208 - val_auc: 0.6857 - val_f1_score: 0.6208 - val_loss: 0.6727 - val_precision: 0.6208 - val_recall: 0.6208
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.7160 - auc: 0.7927 - f1_score: 0.7160 - loss: 0.6520 - precision: 0.7160 - recall: 0.7160
# Epoch 4: val_accuracy improved from 0.62083 to 0.71875, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.7160 - auc: 0.7927 - f1_score: 0.7160 - loss: 0.6521 - precision: 0.7160 - recall: 0.7160 - val_accuracy: 0.7188 - val_auc: 0.8130 - val_f1_score: 0.7187 - val_loss: 0.5365 - val_precision: 0.7188 - val_recall: 0.7188
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.7401 - auc: 0.8181 - f1_score: 0.7401 - loss: 0.6286 - precision: 0.7401 - recall: 0.7401
# Epoch 5: val_accuracy improved from 0.71875 to 0.81458, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 523ms/step - accuracy: 0.7403 - auc: 0.8184 - f1_score: 0.7403 - loss: 0.6279 - precision: 0.7403 - recall: 0.7403 - val_accuracy: 0.8146 - val_auc: 0.8955 - val_f1_score: 0.8146 - val_loss: 0.4112 - val_precision: 0.8146 - val_recall: 0.8146
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8187 - auc: 0.8945 - f1_score: 0.8187 - loss: 0.4472 - precision: 0.8187 - recall: 0.8187
# Epoch 6: val_accuracy improved from 0.81458 to 0.86667, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 522ms/step - accuracy: 0.8194 - auc: 0.8952 - f1_score: 0.8194 - loss: 0.4457 - precision: 0.8194 - recall: 0.8194 - val_accuracy: 0.8667 - val_auc: 0.9417 - val_f1_score: 0.8667 - val_loss: 0.3114 - val_precision: 0.8667 - val_recall: 0.8667
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8281 - auc: 0.9089 - f1_score: 0.8281 - loss: 0.4383 - precision: 0.8281 - recall: 0.8281
# Epoch 7: val_accuracy improved from 0.86667 to 0.87708, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 527ms/step - accuracy: 0.8284 - auc: 0.9092 - f1_score: 0.8284 - loss: 0.4377 - precision: 0.8284 - recall: 0.8284 - val_accuracy: 0.8771 - val_auc: 0.9572 - val_f1_score: 0.8771 - val_loss: 0.2778 - val_precision: 0.8771 - val_recall: 0.8771
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.8616 - auc: 0.9367 - f1_score: 0.8616 - loss: 0.3624 - precision: 0.8616 - recall: 0.8616
# Epoch 8: val_accuracy did not improve from 0.87708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 547ms/step - accuracy: 0.8618 - auc: 0.9369 - f1_score: 0.8618 - loss: 0.3615 - precision: 0.8618 - recall: 0.8618 - val_accuracy: 0.8354 - val_auc: 0.9242 - val_f1_score: 0.8354 - val_loss: 0.4575 - val_precision: 0.8354 - val_recall: 0.8354
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8523 - auc: 0.9221 - f1_score: 0.8523 - loss: 0.4316 - precision: 0.8523 - recall: 0.8523
# Epoch 9: val_accuracy did not improve from 0.87708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 498ms/step - accuracy: 0.8530 - auc: 0.9226 - f1_score: 0.8530 - loss: 0.4295 - precision: 0.8530 - recall: 0.8530 - val_accuracy: 0.8271 - val_auc: 0.9203 - val_f1_score: 0.8271 - val_loss: 0.4131 - val_precision: 0.8271 - val_recall: 0.8271
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8893 - auc: 0.9586 - f1_score: 0.8893 - loss: 0.2711 - precision: 0.8893 - recall: 0.8893
# Epoch 10: val_accuracy did not improve from 0.87708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.8893 - auc: 0.9585 - f1_score: 0.8893 - loss: 0.2717 - precision: 0.8893 - recall: 0.8893 - val_accuracy: 0.8271 - val_auc: 0.9317 - val_f1_score: 0.8271 - val_loss: 0.3861 - val_precision: 0.8271 - val_recall: 0.8271
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9010 - auc: 0.9618 - f1_score: 0.9010 - loss: 0.2726 - precision: 0.9010 - recall: 0.9010
# Epoch 11: val_accuracy improved from 0.87708 to 0.92292, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 523ms/step - accuracy: 0.9014 - auc: 0.9621 - f1_score: 0.9014 - loss: 0.2711 - precision: 0.9014 - recall: 0.9014 - val_accuracy: 0.9229 - val_auc: 0.9663 - val_f1_score: 0.9229 - val_loss: 0.2504 - val_precision: 0.9229 - val_recall: 0.9229
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9254 - auc: 0.9782 - f1_score: 0.9254 - loss: 0.1944 - precision: 0.9254 - recall: 0.9254
# Epoch 12: val_accuracy did not improve from 0.92292
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9255 - auc: 0.9782 - f1_score: 0.9255 - loss: 0.1944 - precision: 0.9255 - recall: 0.9255 - val_accuracy: 0.8771 - val_auc: 0.9573 - val_f1_score: 0.8771 - val_loss: 0.3394 - val_precision: 0.8771 - val_recall: 0.8771
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9239 - auc: 0.9731 - f1_score: 0.9239 - loss: 0.2214 - precision: 0.9239 - recall: 0.9239
# Epoch 13: val_accuracy improved from 0.92292 to 0.92917, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 521ms/step - accuracy: 0.9239 - auc: 0.9732 - f1_score: 0.9239 - loss: 0.2213 - precision: 0.9239 - recall: 0.9239 - val_accuracy: 0.9292 - val_auc: 0.9789 - val_f1_score: 0.9292 - val_loss: 0.2031 - val_precision: 0.9292 - val_recall: 0.9292
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9400 - auc: 0.9882 - f1_score: 0.9400 - loss: 0.1403 - precision: 0.9400 - recall: 0.9400
# Epoch 14: val_accuracy did not improve from 0.92917
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9397 - auc: 0.9880 - f1_score: 0.9397 - loss: 0.1414 - precision: 0.9397 - recall: 0.9397 - val_accuracy: 0.8396 - val_auc: 0.9286 - val_f1_score: 0.8396 - val_loss: 0.4516 - val_precision: 0.8396 - val_recall: 0.8396
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9269 - auc: 0.9802 - f1_score: 0.9269 - loss: 0.1930 - precision: 0.9269 - recall: 0.9269
# Epoch 15: val_accuracy improved from 0.92917 to 0.96458, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 521ms/step - accuracy: 0.9269 - auc: 0.9801 - f1_score: 0.9269 - loss: 0.1933 - precision: 0.9269 - recall: 0.9269 - val_accuracy: 0.9646 - val_auc: 0.9933 - val_f1_score: 0.9646 - val_loss: 0.1025 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9560 - auc: 0.9891 - f1_score: 0.9560 - loss: 0.1252 - precision: 0.9560 - recall: 0.9560
# Epoch 16: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9557 - auc: 0.9890 - f1_score: 0.9557 - loss: 0.1259 - precision: 0.9557 - recall: 0.9557 - val_accuracy: 0.9417 - val_auc: 0.9882 - val_f1_score: 0.9417 - val_loss: 0.1377 - val_precision: 0.9417 - val_recall: 0.9417
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9500 - auc: 0.9893 - f1_score: 0.9500 - loss: 0.1314 - precision: 0.9500 - recall: 0.9500
# Epoch 17: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 553ms/step - accuracy: 0.9498 - auc: 0.9892 - f1_score: 0.9498 - loss: 0.1318 - precision: 0.9498 - recall: 0.9498 - val_accuracy: 0.9563 - val_auc: 0.9854 - val_f1_score: 0.9562 - val_loss: 0.1562 - val_precision: 0.9563 - val_recall: 0.9563
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9513 - auc: 0.9854 - f1_score: 0.9513 - loss: 0.1490 - precision: 0.9513 - recall: 0.9513
# Epoch 18: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9510 - auc: 0.9854 - f1_score: 0.9510 - loss: 0.1495 - precision: 0.9510 - recall: 0.9510 - val_accuracy: 0.9646 - val_auc: 0.9937 - val_f1_score: 0.9646 - val_loss: 0.1078 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9685 - auc: 0.9930 - f1_score: 0.9685 - loss: 0.1017 - precision: 0.9685 - recall: 0.9685
# Epoch 19: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 498ms/step - accuracy: 0.9684 - auc: 0.9930 - f1_score: 0.9684 - loss: 0.1017 - precision: 0.9684 - recall: 0.9684 - val_accuracy: 0.9271 - val_auc: 0.9855 - val_f1_score: 0.9271 - val_loss: 0.1817 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9551 - auc: 0.9904 - f1_score: 0.9551 - loss: 0.1170 - precision: 0.9551 - recall: 0.9551
# Epoch 20: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9552 - auc: 0.9904 - f1_score: 0.9552 - loss: 0.1171 - precision: 0.9552 - recall: 0.9552 - val_accuracy: 0.9396 - val_auc: 0.9879 - val_f1_score: 0.9396 - val_loss: 0.1629 - val_precision: 0.9396 - val_recall: 0.9396
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9663 - auc: 0.9957 - f1_score: 0.9663 - loss: 0.0847 - precision: 0.9663 - recall: 0.9663
# Epoch 21: val_accuracy did not improve from 0.96458
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9662 - auc: 0.9957 - f1_score: 0.9662 - loss: 0.0850 - precision: 0.9662 - recall: 0.9662 - val_accuracy: 0.9417 - val_auc: 0.9810 - val_f1_score: 0.9417 - val_loss: 0.1902 - val_precision: 0.9417 - val_recall: 0.9417
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9628 - auc: 0.9912 - f1_score: 0.9628 - loss: 0.1071 - precision: 0.9628 - recall: 0.9628
# Epoch 22: val_accuracy improved from 0.96458 to 0.96667, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 520ms/step - accuracy: 0.9627 - auc: 0.9912 - f1_score: 0.9627 - loss: 0.1074 - precision: 0.9627 - recall: 0.9627 - val_accuracy: 0.9667 - val_auc: 0.9959 - val_f1_score: 0.9667 - val_loss: 0.0831 - val_precision: 0.9667 - val_recall: 0.9667
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9565 - auc: 0.9925 - f1_score: 0.9565 - loss: 0.1117 - precision: 0.9565 - recall: 0.9565
# Epoch 23: val_accuracy did not improve from 0.96667
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9564 - auc: 0.9925 - f1_score: 0.9564 - loss: 0.1120 - precision: 0.9564 - recall: 0.9564 - val_accuracy: 0.9500 - val_auc: 0.9885 - val_f1_score: 0.9500 - val_loss: 0.1308 - val_precision: 0.9500 - val_recall: 0.9500
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9576 - auc: 0.9934 - f1_score: 0.9576 - loss: 0.1084 - precision: 0.9576 - recall: 0.9576
# Epoch 24: val_accuracy improved from 0.96667 to 0.97708, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 521ms/step - accuracy: 0.9576 - auc: 0.9934 - f1_score: 0.9576 - loss: 0.1089 - precision: 0.9576 - recall: 0.9576 - val_accuracy: 0.9771 - val_auc: 0.9968 - val_f1_score: 0.9771 - val_loss: 0.0714 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9528 - auc: 0.9821 - f1_score: 0.9528 - loss: 0.1568 - precision: 0.9528 - recall: 0.9528
# Epoch 25: val_accuracy did not improve from 0.97708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 497ms/step - accuracy: 0.9530 - auc: 0.9823 - f1_score: 0.9530 - loss: 0.1559 - precision: 0.9530 - recall: 0.9530 - val_accuracy: 0.9625 - val_auc: 0.9910 - val_f1_score: 0.9625 - val_loss: 0.1024 - val_precision: 0.9625 - val_recall: 0.9625
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9699 - auc: 0.9967 - f1_score: 0.9699 - loss: 0.0724 - precision: 0.9699 - recall: 0.9699
# Epoch 26: val_accuracy did not improve from 0.97708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9700 - auc: 0.9967 - f1_score: 0.9700 - loss: 0.0725 - precision: 0.9700 - recall: 0.9700 - val_accuracy: 0.9521 - val_auc: 0.9912 - val_f1_score: 0.9521 - val_loss: 0.1188 - val_precision: 0.9521 - val_recall: 0.9521
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9607 - auc: 0.9931 - f1_score: 0.9607 - loss: 0.1051 - precision: 0.9607 - recall: 0.9607
# Epoch 27: val_accuracy did not improve from 0.97708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9607 - auc: 0.9931 - f1_score: 0.9607 - loss: 0.1052 - precision: 0.9607 - recall: 0.9607 - val_accuracy: 0.9646 - val_auc: 0.9949 - val_f1_score: 0.9646 - val_loss: 0.0959 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9676 - auc: 0.9905 - f1_score: 0.9676 - loss: 0.1050 - precision: 0.9676 - recall: 0.9676
# Epoch 28: val_accuracy did not improve from 0.97708
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9677 - auc: 0.9905 - f1_score: 0.9677 - loss: 0.1048 - precision: 0.9677 - recall: 0.9677 - val_accuracy: 0.9646 - val_auc: 0.9961 - val_f1_score: 0.9646 - val_loss: 0.0825 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9580 - auc: 0.9916 - f1_score: 0.9580 - loss: 0.1167 - precision: 0.9580 - recall: 0.9580
# Epoch 29: val_accuracy improved from 0.97708 to 0.97917, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 520ms/step - accuracy: 0.9580 - auc: 0.9915 - f1_score: 0.9580 - loss: 0.1170 - precision: 0.9580 - recall: 0.9580 - val_accuracy: 0.9792 - val_auc: 0.9976 - val_f1_score: 0.9792 - val_loss: 0.0633 - val_precision: 0.9792 - val_recall: 0.9792
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9644 - auc: 0.9943 - f1_score: 0.9644 - loss: 0.0931 - precision: 0.9644 - recall: 0.9644
# Epoch 30: val_accuracy improved from 0.97917 to 0.98125, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 522ms/step - accuracy: 0.9643 - auc: 0.9943 - f1_score: 0.9643 - loss: 0.0933 - precision: 0.9643 - recall: 0.9643 - val_accuracy: 0.9812 - val_auc: 0.9986 - val_f1_score: 0.9812 - val_loss: 0.0496 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9715 - auc: 0.9922 - f1_score: 0.9715 - loss: 0.0919 - precision: 0.9715 - recall: 0.9715
# Epoch 31: val_accuracy did not improve from 0.98125
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9714 - auc: 0.9922 - f1_score: 0.9714 - loss: 0.0921 - precision: 0.9714 - recall: 0.9714 - val_accuracy: 0.9812 - val_auc: 0.9983 - val_f1_score: 0.9812 - val_loss: 0.0525 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9621 - auc: 0.9922 - f1_score: 0.9621 - loss: 0.1068 - precision: 0.9621 - recall: 0.9621
# Epoch 32: val_accuracy did not improve from 0.98125
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9623 - auc: 0.9923 - f1_score: 0.9623 - loss: 0.1061 - precision: 0.9623 - recall: 0.9623 - val_accuracy: 0.9563 - val_auc: 0.9899 - val_f1_score: 0.9563 - val_loss: 0.1271 - val_precision: 0.9563 - val_recall: 0.9563
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9738 - auc: 0.9942 - f1_score: 0.9738 - loss: 0.0941 - precision: 0.9738 - recall: 0.9738
# Epoch 33: val_accuracy did not improve from 0.98125
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9738 - auc: 0.9942 - f1_score: 0.9738 - loss: 0.0939 - precision: 0.9738 - recall: 0.9738 - val_accuracy: 0.9792 - val_auc: 0.9982 - val_f1_score: 0.9792 - val_loss: 0.0552 - val_precision: 0.9792 - val_recall: 0.9792
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9587 - auc: 0.9937 - f1_score: 0.9587 - loss: 0.1029 - precision: 0.9587 - recall: 0.9587
# Epoch 34: val_accuracy did not improve from 0.98125
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9589 - auc: 0.9937 - f1_score: 0.9589 - loss: 0.1025 - precision: 0.9589 - recall: 0.9589 - val_accuracy: 0.9646 - val_auc: 0.9968 - val_f1_score: 0.9646 - val_loss: 0.0748 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9783 - auc: 0.9976 - f1_score: 0.9783 - loss: 0.0555 - precision: 0.9783 - recall: 0.9783
# Epoch 35: val_accuracy did not improve from 0.98125
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9784 - auc: 0.9976 - f1_score: 0.9784 - loss: 0.0555 - precision: 0.9784 - recall: 0.9784 - val_accuracy: 0.9688 - val_auc: 0.9971 - val_f1_score: 0.9688 - val_loss: 0.0686 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9800 - auc: 0.9985 - f1_score: 0.9800 - loss: 0.0515 - precision: 0.9800 - recall: 0.9800
# Epoch 36: val_accuracy improved from 0.98125 to 0.98333, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 520ms/step - accuracy: 0.9799 - auc: 0.9985 - f1_score: 0.9799 - loss: 0.0515 - precision: 0.9799 - recall: 0.9799 - val_accuracy: 0.9833 - val_auc: 0.9994 - val_f1_score: 0.9833 - val_loss: 0.0350 - val_precision: 0.9833 - val_recall: 0.9833
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9781 - auc: 0.9954 - f1_score: 0.9781 - loss: 0.0753 - precision: 0.9781 - recall: 0.9781
# Epoch 37: val_accuracy improved from 0.98333 to 0.98542, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 520ms/step - accuracy: 0.9781 - auc: 0.9954 - f1_score: 0.9781 - loss: 0.0753 - precision: 0.9781 - recall: 0.9781 - val_accuracy: 0.9854 - val_auc: 0.9987 - val_f1_score: 0.9854 - val_loss: 0.0439 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9698 - auc: 0.9960 - f1_score: 0.9698 - loss: 0.0841 - precision: 0.9698 - recall: 0.9698
# Epoch 38: val_accuracy did not improve from 0.98542
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 498ms/step - accuracy: 0.9697 - auc: 0.9959 - f1_score: 0.9697 - loss: 0.0844 - precision: 0.9697 - recall: 0.9697 - val_accuracy: 0.9646 - val_auc: 0.9974 - val_f1_score: 0.9646 - val_loss: 0.0669 - val_precision: 0.9646 - val_recall: 0.9646
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9659 - auc: 0.9954 - f1_score: 0.9659 - loss: 0.0917 - precision: 0.9659 - recall: 0.9659
# Epoch 39: val_accuracy did not improve from 0.98542
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9660 - auc: 0.9955 - f1_score: 0.9660 - loss: 0.0915 - precision: 0.9660 - recall: 0.9660 - val_accuracy: 0.9688 - val_auc: 0.9917 - val_f1_score: 0.9688 - val_loss: 0.0923 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9835 - auc: 0.9980 - f1_score: 0.9835 - loss: 0.0469 - precision: 0.9835 - recall: 0.9835
# Epoch 40: val_accuracy did not improve from 0.98542
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9835 - auc: 0.9980 - f1_score: 0.9835 - loss: 0.0470 - precision: 0.9835 - recall: 0.9835 - val_accuracy: 0.9792 - val_auc: 0.9985 - val_f1_score: 0.9792 - val_loss: 0.0539 - val_precision: 0.9792 - val_recall: 0.9792
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9822 - auc: 0.9985 - f1_score: 0.9822 - loss: 0.0508 - precision: 0.9822 - recall: 0.9822
# Epoch 41: val_accuracy improved from 0.98542 to 0.99167, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 521ms/step - accuracy: 0.9822 - auc: 0.9985 - f1_score: 0.9822 - loss: 0.0508 - precision: 0.9822 - recall: 0.9822 - val_accuracy: 0.9917 - val_auc: 0.9996 - val_f1_score: 0.9917 - val_loss: 0.0293 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9826 - auc: 0.9987 - f1_score: 0.9826 - loss: 0.0415 - precision: 0.9826 - recall: 0.9826
# Epoch 42: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9826 - auc: 0.9987 - f1_score: 0.9826 - loss: 0.0416 - precision: 0.9826 - recall: 0.9826 - val_accuracy: 0.9896 - val_auc: 0.9991 - val_f1_score: 0.9896 - val_loss: 0.0361 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9818 - auc: 0.9978 - f1_score: 0.9818 - loss: 0.0491 - precision: 0.9818 - recall: 0.9818
# Epoch 43: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9817 - auc: 0.9978 - f1_score: 0.9817 - loss: 0.0493 - precision: 0.9817 - recall: 0.9817 - val_accuracy: 0.9604 - val_auc: 0.9941 - val_f1_score: 0.9604 - val_loss: 0.1030 - val_precision: 0.9604 - val_recall: 0.9604
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9699 - auc: 0.9966 - f1_score: 0.9699 - loss: 0.0660 - precision: 0.9699 - recall: 0.9699
# Epoch 44: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9701 - auc: 0.9966 - f1_score: 0.9701 - loss: 0.0661 - precision: 0.9701 - recall: 0.9701 - val_accuracy: 0.9729 - val_auc: 0.9970 - val_f1_score: 0.9729 - val_loss: 0.0724 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9747 - auc: 0.9972 - f1_score: 0.9747 - loss: 0.0683 - precision: 0.9747 - recall: 0.9747
# Epoch 45: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9747 - auc: 0.9972 - f1_score: 0.9747 - loss: 0.0682 - precision: 0.9747 - recall: 0.9747 - val_accuracy: 0.9708 - val_auc: 0.9951 - val_f1_score: 0.9708 - val_loss: 0.0761 - val_precision: 0.9708 - val_recall: 0.9708
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9766 - auc: 0.9971 - f1_score: 0.9766 - loss: 0.0678 - precision: 0.9766 - recall: 0.9766
# Epoch 46: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9768 - auc: 0.9972 - f1_score: 0.9768 - loss: 0.0675 - precision: 0.9768 - recall: 0.9768 - val_accuracy: 0.9896 - val_auc: 0.9997 - val_f1_score: 0.9896 - val_loss: 0.0274 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9776 - auc: 0.9956 - f1_score: 0.9776 - loss: 0.0645 - precision: 0.9776 - recall: 0.9776
# Epoch 47: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9774 - auc: 0.9955 - f1_score: 0.9774 - loss: 0.0650 - precision: 0.9774 - recall: 0.9774 - val_accuracy: 0.9542 - val_auc: 0.9910 - val_f1_score: 0.9542 - val_loss: 0.1219 - val_precision: 0.9542 - val_recall: 0.9542
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9817 - auc: 0.9979 - f1_score: 0.9817 - loss: 0.0538 - precision: 0.9817 - recall: 0.9817
# Epoch 48: val_accuracy did not improve from 0.99167
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9818 - auc: 0.9979 - f1_score: 0.9818 - loss: 0.0537 - precision: 0.9818 - recall: 0.9818 - val_accuracy: 0.9875 - val_auc: 0.9994 - val_f1_score: 0.9875 - val_loss: 0.0326 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9881 - auc: 0.9989 - f1_score: 0.9881 - loss: 0.0417 - precision: 0.9881 - recall: 0.9881
# Epoch 49: val_accuracy improved from 0.99167 to 0.99375, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 522ms/step - accuracy: 0.9881 - auc: 0.9988 - f1_score: 0.9881 - loss: 0.0418 - precision: 0.9881 - recall: 0.9881 - val_accuracy: 0.9937 - val_auc: 0.9993 - val_f1_score: 0.9937 - val_loss: 0.0333 - val_precision: 0.9937 - val_recall: 0.9937
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9818 - auc: 0.9989 - f1_score: 0.9818 - loss: 0.0404 - precision: 0.9818 - recall: 0.9818
# Epoch 50: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9819 - auc: 0.9989 - f1_score: 0.9819 - loss: 0.0404 - precision: 0.9819 - recall: 0.9819 - val_accuracy: 0.9917 - val_auc: 0.9996 - val_f1_score: 0.9917 - val_loss: 0.0260 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9911 - auc: 0.9993 - f1_score: 0.9911 - loss: 0.0342 - precision: 0.9911 - recall: 0.9911
# Epoch 51: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9910 - auc: 0.9992 - f1_score: 0.9910 - loss: 0.0344 - precision: 0.9910 - recall: 0.9910 - val_accuracy: 0.9896 - val_auc: 0.9997 - val_f1_score: 0.9896 - val_loss: 0.0240 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9795 - auc: 0.9967 - f1_score: 0.9795 - loss: 0.0537 - precision: 0.9795 - recall: 0.9795
# Epoch 52: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9794 - auc: 0.9967 - f1_score: 0.9794 - loss: 0.0537 - precision: 0.9794 - recall: 0.9794 - val_accuracy: 0.9750 - val_auc: 0.9965 - val_f1_score: 0.9750 - val_loss: 0.0792 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9852 - auc: 0.9989 - f1_score: 0.9852 - loss: 0.0400 - precision: 0.9852 - recall: 0.9852
# Epoch 53: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9852 - auc: 0.9989 - f1_score: 0.9852 - loss: 0.0400 - precision: 0.9852 - recall: 0.9852 - val_accuracy: 0.9854 - val_auc: 0.9992 - val_f1_score: 0.9854 - val_loss: 0.0362 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9817 - auc: 0.9983 - f1_score: 0.9817 - loss: 0.0507 - precision: 0.9817 - recall: 0.9817
# Epoch 54: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9817 - auc: 0.9983 - f1_score: 0.9817 - loss: 0.0508 - precision: 0.9817 - recall: 0.9817 - val_accuracy: 0.9271 - val_auc: 0.9828 - val_f1_score: 0.9271 - val_loss: 0.1765 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9773 - auc: 0.9983 - f1_score: 0.9773 - loss: 0.0527 - precision: 0.9773 - recall: 0.9773
# Epoch 55: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9773 - auc: 0.9984 - f1_score: 0.9773 - loss: 0.0527 - precision: 0.9773 - recall: 0.9773 - val_accuracy: 0.9812 - val_auc: 0.9984 - val_f1_score: 0.9812 - val_loss: 0.0512 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9782 - auc: 0.9969 - f1_score: 0.9782 - loss: 0.0608 - precision: 0.9782 - recall: 0.9782
# Epoch 56: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9782 - auc: 0.9969 - f1_score: 0.9782 - loss: 0.0606 - precision: 0.9782 - recall: 0.9782 - val_accuracy: 0.9750 - val_auc: 0.9987 - val_f1_score: 0.9750 - val_loss: 0.0485 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9861 - auc: 0.9995 - f1_score: 0.9861 - loss: 0.0284 - precision: 0.9861 - recall: 0.9861
# Epoch 57: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9860 - auc: 0.9994 - f1_score: 0.9860 - loss: 0.0289 - precision: 0.9860 - recall: 0.9860 - val_accuracy: 0.9937 - val_auc: 0.9998 - val_f1_score: 0.9937 - val_loss: 0.0193 - val_precision: 0.9937 - val_recall: 0.9937
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9846 - auc: 0.9974 - f1_score: 0.9846 - loss: 0.0486 - precision: 0.9846 - recall: 0.9846
# Epoch 58: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9847 - auc: 0.9974 - f1_score: 0.9847 - loss: 0.0485 - precision: 0.9847 - recall: 0.9847 - val_accuracy: 0.9625 - val_auc: 0.9969 - val_f1_score: 0.9625 - val_loss: 0.0737 - val_precision: 0.9625 - val_recall: 0.9625
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9920 - auc: 0.9999 - f1_score: 0.9920 - loss: 0.0172 - precision: 0.9920 - recall: 0.9920
# Epoch 59: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9919 - auc: 0.9999 - f1_score: 0.9919 - loss: 0.0174 - precision: 0.9919 - recall: 0.9919 - val_accuracy: 0.9937 - val_auc: 0.9998 - val_f1_score: 0.9937 - val_loss: 0.0213 - val_precision: 0.9937 - val_recall: 0.9937
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9804 - auc: 0.9988 - f1_score: 0.9804 - loss: 0.0418 - precision: 0.9804 - recall: 0.9804
# Epoch 60: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9803 - auc: 0.9988 - f1_score: 0.9803 - loss: 0.0423 - precision: 0.9803 - recall: 0.9803 - val_accuracy: 0.9563 - val_auc: 0.9950 - val_f1_score: 0.9563 - val_loss: 0.0965 - val_precision: 0.9563 - val_recall: 0.9563
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9750 - auc: 0.9970 - f1_score: 0.9750 - loss: 0.0716 - precision: 0.9750 - recall: 0.9750
# Epoch 61: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9751 - auc: 0.9971 - f1_score: 0.9751 - loss: 0.0712 - precision: 0.9751 - recall: 0.9751 - val_accuracy: 0.9729 - val_auc: 0.9974 - val_f1_score: 0.9729 - val_loss: 0.0675 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9870 - auc: 0.9991 - f1_score: 0.9870 - loss: 0.0321 - precision: 0.9870 - recall: 0.9870
# Epoch 62: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9870 - auc: 0.9991 - f1_score: 0.9870 - loss: 0.0322 - precision: 0.9870 - recall: 0.9870 - val_accuracy: 0.9729 - val_auc: 0.9951 - val_f1_score: 0.9729 - val_loss: 0.0740 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9748 - auc: 0.9976 - f1_score: 0.9748 - loss: 0.0707 - precision: 0.9748 - recall: 0.9748
# Epoch 63: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9749 - auc: 0.9976 - f1_score: 0.9749 - loss: 0.0702 - precision: 0.9749 - recall: 0.9749 - val_accuracy: 0.9812 - val_auc: 0.9984 - val_f1_score: 0.9812 - val_loss: 0.0511 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9945 - auc: 0.9995 - f1_score: 0.9945 - loss: 0.0259 - precision: 0.9945 - recall: 0.9945
# Epoch 64: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9944 - auc: 0.9995 - f1_score: 0.9944 - loss: 0.0261 - precision: 0.9944 - recall: 0.9944 - val_accuracy: 0.9896 - val_auc: 0.9996 - val_f1_score: 0.9896 - val_loss: 0.0280 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9840 - auc: 0.9976 - f1_score: 0.9840 - loss: 0.0490 - precision: 0.9840 - recall: 0.9840
# Epoch 65: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9839 - auc: 0.9976 - f1_score: 0.9839 - loss: 0.0489 - precision: 0.9839 - recall: 0.9839 - val_accuracy: 0.9771 - val_auc: 0.9992 - val_f1_score: 0.9771 - val_loss: 0.0360 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9847 - auc: 0.9982 - f1_score: 0.9847 - loss: 0.0433 - precision: 0.9847 - recall: 0.9847
# Epoch 66: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9848 - auc: 0.9982 - f1_score: 0.9848 - loss: 0.0433 - precision: 0.9848 - recall: 0.9848 - val_accuracy: 0.9854 - val_auc: 0.9967 - val_f1_score: 0.9854 - val_loss: 0.0552 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9773 - auc: 0.9984 - f1_score: 0.9773 - loss: 0.0481 - precision: 0.9773 - recall: 0.9773
# Epoch 67: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9774 - auc: 0.9984 - f1_score: 0.9774 - loss: 0.0479 - precision: 0.9774 - recall: 0.9774 - val_accuracy: 0.9875 - val_auc: 0.9993 - val_f1_score: 0.9875 - val_loss: 0.0351 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9836 - auc: 0.9983 - f1_score: 0.9836 - loss: 0.0480 - precision: 0.9836 - recall: 0.9836
# Epoch 68: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9836 - auc: 0.9983 - f1_score: 0.9836 - loss: 0.0480 - precision: 0.9836 - recall: 0.9836 - val_accuracy: 0.9500 - val_auc: 0.9897 - val_f1_score: 0.9500 - val_loss: 0.1301 - val_precision: 0.9500 - val_recall: 0.9500
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9834 - auc: 0.9990 - f1_score: 0.9834 - loss: 0.0410 - precision: 0.9834 - recall: 0.9834
# Epoch 69: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9835 - auc: 0.9990 - f1_score: 0.9835 - loss: 0.0409 - precision: 0.9835 - recall: 0.9835 - val_accuracy: 0.9104 - val_auc: 0.9707 - val_f1_score: 0.9104 - val_loss: 0.2308 - val_precision: 0.9104 - val_recall: 0.9104
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9879 - auc: 0.9995 - f1_score: 0.9879 - loss: 0.0294 - precision: 0.9879 - recall: 0.9879
# Epoch 70: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9878 - auc: 0.9995 - f1_score: 0.9878 - loss: 0.0295 - precision: 0.9878 - recall: 0.9878 - val_accuracy: 0.9521 - val_auc: 0.9919 - val_f1_score: 0.9521 - val_loss: 0.1117 - val_precision: 0.9521 - val_recall: 0.9521
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9852 - auc: 0.9986 - f1_score: 0.9852 - loss: 0.0386 - precision: 0.9852 - recall: 0.9852
# Epoch 71: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9852 - auc: 0.9986 - f1_score: 0.9852 - loss: 0.0386 - precision: 0.9852 - recall: 0.9852 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_f1_score: 0.9833 - val_loss: 0.0427 - val_precision: 0.9833 - val_recall: 0.9833
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9835 - auc: 0.9985 - f1_score: 0.9835 - loss: 0.0510 - precision: 0.9835 - recall: 0.9835
# Epoch 72: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9835 - auc: 0.9985 - f1_score: 0.9835 - loss: 0.0508 - precision: 0.9835 - recall: 0.9835 - val_accuracy: 0.9708 - val_auc: 0.9977 - val_f1_score: 0.9708 - val_loss: 0.0649 - val_precision: 0.9708 - val_recall: 0.9708
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9774 - auc: 0.9977 - f1_score: 0.9774 - loss: 0.0639 - precision: 0.9774 - recall: 0.9774
# Epoch 73: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9775 - auc: 0.9977 - f1_score: 0.9775 - loss: 0.0634 - precision: 0.9775 - recall: 0.9775 - val_accuracy: 0.9875 - val_auc: 0.9991 - val_f1_score: 0.9875 - val_loss: 0.0391 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9840 - auc: 0.9991 - f1_score: 0.9840 - loss: 0.0386 - precision: 0.9840 - recall: 0.9840
# Epoch 74: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9841 - auc: 0.9992 - f1_score: 0.9841 - loss: 0.0384 - precision: 0.9841 - recall: 0.9841 - val_accuracy: 0.9771 - val_auc: 0.9945 - val_f1_score: 0.9771 - val_loss: 0.0709 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9889 - auc: 0.9978 - f1_score: 0.9889 - loss: 0.0331 - precision: 0.9889 - recall: 0.9889
# Epoch 75: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9889 - auc: 0.9978 - f1_score: 0.9889 - loss: 0.0332 - precision: 0.9889 - recall: 0.9889 - val_accuracy: 0.9854 - val_auc: 0.9996 - val_f1_score: 0.9854 - val_loss: 0.0274 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9922 - auc: 0.9994 - f1_score: 0.9922 - loss: 0.0234 - precision: 0.9922 - recall: 0.9922
# Epoch 76: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9922 - auc: 0.9994 - f1_score: 0.9922 - loss: 0.0237 - precision: 0.9922 - recall: 0.9922 - val_accuracy: 0.9917 - val_auc: 0.9999 - val_f1_score: 0.9917 - val_loss: 0.0177 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9896 - auc: 0.9994 - f1_score: 0.9896 - loss: 0.0300 - precision: 0.9896 - recall: 0.9896
# Epoch 77: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9896 - auc: 0.9994 - f1_score: 0.9896 - loss: 0.0300 - precision: 0.9896 - recall: 0.9896 - val_accuracy: 0.9708 - val_auc: 0.9947 - val_f1_score: 0.9708 - val_loss: 0.0868 - val_precision: 0.9708 - val_recall: 0.9708
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9842 - auc: 0.9981 - f1_score: 0.9842 - loss: 0.0442 - precision: 0.9842 - recall: 0.9842
# Epoch 78: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9842 - auc: 0.9981 - f1_score: 0.9842 - loss: 0.0442 - precision: 0.9842 - recall: 0.9842 - val_accuracy: 0.9771 - val_auc: 0.9951 - val_f1_score: 0.9771 - val_loss: 0.0687 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9883 - auc: 0.9997 - f1_score: 0.9883 - loss: 0.0259 - precision: 0.9883 - recall: 0.9883
# Epoch 79: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9884 - auc: 0.9997 - f1_score: 0.9884 - loss: 0.0259 - precision: 0.9884 - recall: 0.9884 - val_accuracy: 0.9937 - val_auc: 0.9999 - val_f1_score: 0.9937 - val_loss: 0.0194 - val_precision: 0.9937 - val_recall: 0.9937
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9875 - auc: 0.9992 - f1_score: 0.9875 - loss: 0.0318 - precision: 0.9875 - recall: 0.9875
# Epoch 80: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9875 - auc: 0.9991 - f1_score: 0.9875 - loss: 0.0320 - precision: 0.9875 - recall: 0.9875 - val_accuracy: 0.9604 - val_auc: 0.9933 - val_f1_score: 0.9604 - val_loss: 0.0921 - val_precision: 0.9604 - val_recall: 0.9604
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9906 - auc: 0.9991 - f1_score: 0.9906 - loss: 0.0338 - precision: 0.9906 - recall: 0.9906
# Epoch 81: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 494ms/step - accuracy: 0.9905 - auc: 0.9991 - f1_score: 0.9905 - loss: 0.0337 - precision: 0.9905 - recall: 0.9905 - val_accuracy: 0.9354 - val_auc: 0.9891 - val_f1_score: 0.9354 - val_loss: 0.1376 - val_precision: 0.9354 - val_recall: 0.9354
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9873 - auc: 0.9990 - f1_score: 0.9873 - loss: 0.0321 - precision: 0.9873 - recall: 0.9873
# Epoch 82: val_accuracy did not improve from 0.99375
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9873 - auc: 0.9990 - f1_score: 0.9873 - loss: 0.0322 - precision: 0.9873 - recall: 0.9873 - val_accuracy: 0.9854 - val_auc: 0.9994 - val_f1_score: 0.9854 - val_loss: 0.0312 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9850 - auc: 0.9986 - f1_score: 0.9850 - loss: 0.0439 - precision: 0.9850 - recall: 0.9850
# Epoch 83: val_accuracy improved from 0.99375 to 0.99583, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 522ms/step - accuracy: 0.9851 - auc: 0.9986 - f1_score: 0.9851 - loss: 0.0436 - precision: 0.9851 - recall: 0.9851 - val_accuracy: 0.9958 - val_auc: 1.0000 - val_f1_score: 0.9958 - val_loss: 0.0124 - val_precision: 0.9958 - val_recall: 0.9958
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9937 - auc: 0.9999 - f1_score: 0.9937 - loss: 0.0187 - precision: 0.9937 - recall: 0.9937
# Epoch 84: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9937 - auc: 0.9999 - f1_score: 0.9937 - loss: 0.0187 - precision: 0.9937 - recall: 0.9937 - val_accuracy: 0.9854 - val_auc: 0.9991 - val_f1_score: 0.9854 - val_loss: 0.0406 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9953 - auc: 0.9985 - f1_score: 0.9953 - loss: 0.0231 - precision: 0.9953 - recall: 0.9953
# Epoch 85: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 496ms/step - accuracy: 0.9952 - auc: 0.9985 - f1_score: 0.9952 - loss: 0.0233 - precision: 0.9952 - recall: 0.9952 - val_accuracy: 0.9812 - val_auc: 0.9986 - val_f1_score: 0.9812 - val_loss: 0.0500 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9958 - auc: 0.9998 - f1_score: 0.9958 - loss: 0.0158 - precision: 0.9958 - recall: 0.9958
# Epoch 86: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 497ms/step - accuracy: 0.9958 - auc: 0.9998 - f1_score: 0.9958 - loss: 0.0158 - precision: 0.9958 - recall: 0.9958 - val_accuracy: 0.9854 - val_auc: 0.9993 - val_f1_score: 0.9854 - val_loss: 0.0338 - val_precision: 0.9854 - val_recall: 0.9854
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9874 - auc: 0.9987 - f1_score: 0.9874 - loss: 0.0421 - precision: 0.9874 - recall: 0.9874
# Epoch 87: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 494ms/step - accuracy: 0.9874 - auc: 0.9987 - f1_score: 0.9874 - loss: 0.0422 - precision: 0.9874 - recall: 0.9874 - val_accuracy: 0.9917 - val_auc: 0.9996 - val_f1_score: 0.9917 - val_loss: 0.0269 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9846 - auc: 0.9983 - f1_score: 0.9846 - loss: 0.0509 - precision: 0.9846 - recall: 0.9846
# Epoch 88: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 494ms/step - accuracy: 0.9847 - auc: 0.9982 - f1_score: 0.9847 - loss: 0.0509 - precision: 0.9847 - recall: 0.9847 - val_accuracy: 0.9917 - val_auc: 0.9993 - val_f1_score: 0.9917 - val_loss: 0.0284 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9841 - auc: 0.9991 - f1_score: 0.9841 - loss: 0.0374 - precision: 0.9841 - recall: 0.9841
# Epoch 89: val_accuracy did not improve from 0.99583
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9841 - auc: 0.9991 - f1_score: 0.9841 - loss: 0.0375 - precision: 0.9841 - recall: 0.9841 - val_accuracy: 0.9729 - val_auc: 0.9940 - val_f1_score: 0.9729 - val_loss: 0.0865 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9931 - auc: 0.9994 - f1_score: 0.9931 - loss: 0.0281 - precision: 0.9931 - recall: 0.9931
# Epoch 90: val_accuracy improved from 0.99583 to 1.00000, saving model to model.weights.h5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 522ms/step - accuracy: 0.9931 - auc: 0.9994 - f1_score: 0.9931 - loss: 0.0281 - precision: 0.9931 - recall: 0.9931 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0136 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9832 - auc: 0.9990 - f1_score: 0.9832 - loss: 0.0392 - precision: 0.9832 - recall: 0.9832
# Epoch 91: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9833 - auc: 0.9990 - f1_score: 0.9833 - loss: 0.0388 - precision: 0.9833 - recall: 0.9833 - val_accuracy: 0.9875 - val_auc: 0.9994 - val_f1_score: 0.9875 - val_loss: 0.0295 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9939 - auc: 0.9999 - f1_score: 0.9939 - loss: 0.0156 - precision: 0.9939 - recall: 0.9939
# Epoch 92: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9939 - auc: 0.9999 - f1_score: 0.9939 - loss: 0.0157 - precision: 0.9939 - recall: 0.9939 - val_accuracy: 0.9875 - val_auc: 0.9993 - val_f1_score: 0.9875 - val_loss: 0.0338 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9937 - auc: 0.9988 - f1_score: 0.9937 - loss: 0.0266 - precision: 0.9937 - recall: 0.9937
# Epoch 93: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9937 - auc: 0.9988 - f1_score: 0.9937 - loss: 0.0266 - precision: 0.9937 - recall: 0.9937 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_f1_score: 0.9979 - val_loss: 0.0086 - val_precision: 0.9979 - val_recall: 0.9979
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9930 - auc: 0.9997 - f1_score: 0.9930 - loss: 0.0233 - precision: 0.9930 - recall: 0.9930
# Epoch 94: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9929 - auc: 0.9997 - f1_score: 0.9929 - loss: 0.0233 - precision: 0.9929 - recall: 0.9929 - val_accuracy: 0.9479 - val_auc: 0.9881 - val_f1_score: 0.9479 - val_loss: 0.1521 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9862 - auc: 0.9960 - f1_score: 0.9862 - loss: 0.0491 - precision: 0.9862 - recall: 0.9862
# Epoch 95: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9862 - auc: 0.9961 - f1_score: 0.9862 - loss: 0.0486 - precision: 0.9862 - recall: 0.9862 - val_accuracy: 0.9771 - val_auc: 0.9975 - val_f1_score: 0.9771 - val_loss: 0.0626 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9951 - auc: 0.9992 - f1_score: 0.9951 - loss: 0.0166 - precision: 0.9951 - recall: 0.9951
# Epoch 96: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9950 - auc: 0.9992 - f1_score: 0.9950 - loss: 0.0167 - precision: 0.9950 - recall: 0.9950 - val_accuracy: 0.9917 - val_auc: 0.9993 - val_f1_score: 0.9917 - val_loss: 0.0281 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9910 - auc: 0.9997 - f1_score: 0.9910 - loss: 0.0228 - precision: 0.9910 - recall: 0.9910
# Epoch 97: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 503ms/step - accuracy: 0.9909 - auc: 0.9997 - f1_score: 0.9909 - loss: 0.0228 - precision: 0.9909 - recall: 0.9909 - val_accuracy: 0.9667 - val_auc: 0.9963 - val_f1_score: 0.9667 - val_loss: 0.0864 - val_precision: 0.9667 - val_recall: 0.9667
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9888 - auc: 0.9996 - f1_score: 0.9888 - loss: 0.0247 - precision: 0.9888 - recall: 0.9888
# Epoch 98: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 500ms/step - accuracy: 0.9886 - auc: 0.9995 - f1_score: 0.9886 - loss: 0.0254 - precision: 0.9886 - recall: 0.9886 - val_accuracy: 0.9917 - val_auc: 0.9998 - val_f1_score: 0.9917 - val_loss: 0.0208 - val_precision: 0.9917 - val_recall: 0.9917
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9852 - auc: 0.9992 - f1_score: 0.9852 - loss: 0.0367 - precision: 0.9852 - recall: 0.9852
# Epoch 99: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9852 - auc: 0.9991 - f1_score: 0.9852 - loss: 0.0369 - precision: 0.9852 - recall: 0.9852 - val_accuracy: 0.9896 - val_auc: 0.9997 - val_f1_score: 0.9896 - val_loss: 0.0264 - val_precision: 0.9896 - val_recall: 0.9896
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9934 - auc: 0.9996 - f1_score: 0.9934 - loss: 0.0237 - precision: 0.9934 - recall: 0.9934
# Epoch 100: val_accuracy did not improve from 1.00000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 495ms/step - accuracy: 0.9934 - auc: 0.9996 - f1_score: 0.9934 - loss: 0.0238 - precision: 0.9934 - recall: 0.9934 - val_accuracy: 0.9792 - val_auc: 0.9995 - val_f1_score: 0.9792 - val_loss: 0.0292 - val_precision: 0.9792 - val_recall: 0.9792

# %% [markdown]
# **Training**

# %%
import matplotlib.pyplot as plt

def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, recall, val_recall, f1_score, val_f1_score):
    fig, axes = plt.subplots(2, 3, figsize=(20, 10))
    fig.suptitle("MODEL'S METRICS VISUALIZATION")

    axes[0, 0].plot(range(1, len(acc) + 1), acc)
    axes[0, 0].plot(range(1, len(val_acc) + 1), val_acc)
    axes[0, 0].set_title('History of Accuracy')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend(['training', 'validation'])

    axes[0, 1].plot(range(1, len(loss) + 1), loss)
    axes[0, 1].plot(range(1, len(val_loss) + 1), val_loss)
    axes[0, 1].set_title('History of Loss')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend(['training', 'validation'])

    axes[0, 2].plot(range(1, len(auc) + 1), auc)
    axes[0, 2].plot(range(1, len(val_auc) + 1), val_auc)
    axes[0, 2].set_title('History of AUC')
    axes[0, 2].set_xlabel('Epochs')
    axes[0, 2].set_ylabel('AUC')
    axes[0, 2].legend(['training', 'validation'])

    axes[1, 0].plot(range(1, len(precision) + 1), precision)
    axes[1, 0].plot(range(1, len(val_precision) + 1), val_precision)
    axes[1, 0].set_title('History of Precision')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Precision')
    axes[1, 0].legend(['training', 'validation'])

    axes[1, 1].plot(range(1, len(recall) + 1), recall)
    axes[1, 1].plot(range(1, len(val_recall) + 1), val_recall)
    axes[1, 1].set_title('History of Recall')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('Recall')
    axes[1, 1].legend(['training', 'validation'])

    axes[1, 2].plot(range(1, len(f1_score) + 1), f1_score)
    axes[1, 2].plot(range(1, len(val_f1_score) + 1), val_f1_score)
    axes[1, 2].set_title('History of F1 score')
    axes[1, 2].set_xlabel('Epochs')
    axes[1, 2].set_ylabel('Recall')  # Corrected from 'Recall' to 'F1 score'
    axes[1, 2].legend(['training', 'validation'])

    plt.tight_layout()
    plt.show()

# Call the function with your history data
Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc']
              )
#history.history['precision'], history.history['val_precision'],
 #              history.history['recall'], history.history['val_recall'],
  #             history.history['f1_score'], history.history['val_f1_score']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 53
#      50     plt.show()
#      52 # Call the function with your history data
# ---> 53 Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
#      54                history.history['loss'], history.history['val_loss'],
#      55                history.history['auc'], history.history['val_auc']
#      56               )
#      57 #history.history['precision'], history.history['val_precision'],
#      58  #              history.history['recall'], history.history['val_recall'],
#      59   #             history.history['f1_score'], history.history['val_f1_score']
#
# NameError: name 'history' is not defined

# %% [markdown]
# **Test**

# %%
def test_image_generator(files):

    batch_paths = files
    batch_x = []
    batch_y = []

    for input_path in batch_paths:
        input = get_input(input_path)
        output = get_output(input_path)
#         if resize is not None:
#             input = cv2.resize(input, resize)
        batch_x.append(input)
        batch_y.append(output)

    batch_x = np.array(batch_x)
    batch_y = np.array(batch_y)

    return batch_x, batch_y

# %%
from keras.models import load_model
x_test,y_test = test_image_generator(Test)

# %%
print(len(x_test))
print(len(y_test))

# %%
model = build_model((299,299,3))  # You need to define the model creation function
optimizer = tf.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, clipnorm=1.0)
model.compile(loss=["categorical_crossentropy"], metrics=METRICS, optimizer = optimizer)

# Load the saved weights
model.load_weights('/kaggle/working/model.weights.h5')
model.evaluate(x_test,y_test,batch_size=1)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 346 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))
# 2024-04-04 05:41:51.652221: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89425: 3.67597, expected 3.20294
# 2024-04-04 05:41:51.652282: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89449: 3.05765, expected 2.58462
# 2024-04-04 05:41:51.652298: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89450: 3.21875, expected 2.74572
# 2024-04-04 05:41:51.652306: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89456: 2.6257, expected 2.15267
# 2024-04-04 05:41:51.652314: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89457: 3.67345, expected 3.20042
# 2024-04-04 05:41:51.652321: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89473: 2.93374, expected 2.46071
# 2024-04-04 05:41:51.652329: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89474: 2.83385, expected 2.36082
# 2024-04-04 05:41:51.652337: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89475: 3.58359, expected 3.11056
# 2024-04-04 05:41:51.652344: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89485: 3.5964, expected 3.12337
# 2024-04-04 05:41:51.652352: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89499: 3.65361, expected 3.18057
# 2024-04-04 05:41:51.652368: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 05:41:51.652376: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 05:41:51.652384: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 05:41:51.652390: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 05:41:51.652397: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 05:41:51.652408: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 05:41:51.685322: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89425: 3.67597, expected 3.20294
# 2024-04-04 05:41:51.685370: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89449: 3.05765, expected 2.58462
# 2024-04-04 05:41:51.685379: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89450: 3.21875, expected 2.74572
# 2024-04-04 05:41:51.685387: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89456: 2.6257, expected 2.15267
# 2024-04-04 05:41:51.685394: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89457: 3.67345, expected 3.20042
# 2024-04-04 05:41:51.685402: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89473: 2.93374, expected 2.46071
# 2024-04-04 05:41:51.685410: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89474: 2.83385, expected 2.36082
# 2024-04-04 05:41:51.685426: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89475: 3.58359, expected 3.11056
# 2024-04-04 05:41:51.685434: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89485: 3.5964, expected 3.12337
# 2024-04-04 05:41:51.685441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 89499: 3.65361, expected 3.18057
# 2024-04-04 05:41:51.685457: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 05:41:51.685467: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 05:41:51.685474: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 05:41:51.685480: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 05:41:51.685487: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 05:41:51.685497: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#    16/20000 ━━━━━━━━━━━━━━━━━━━━ 3:32 11ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712209314.185976     273 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20000/20000 ━━━━━━━━━━━━━━━━━━━━ 211s 10ms/step - accuracy: 0.9960 - auc: 0.9999 - f1_score: 0.9960 - loss: 0.0119 - precision: 0.9960 - recall: 0.9960
# [0.017377445474267006,
#  0.994350016117096,
#  0.9998388290405273,
#  0.9943498969078064,
#  0.994350016117096,
#  0.994350016117096]

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues, fontsize=18):
    """ 
    This function prints and plots the confusion matrix. 
    Normalization can be applied by setting normalize=True. 
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black",
                 fontsize=fontsize)  # Set fontsize here

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Rest of your code...

# Example usage:
Y_pred = model.predict(x_test)

# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred,axis=1)

# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test,axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# Plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(2), fontsize=18)
# Out:
# 2024-04-04 05:46:05.458333: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.14422, expected 3.389
# 2024-04-04 05:46:05.458393: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.90007, expected 5.14485
# 2024-04-04 05:46:05.458408: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.30012, expected 5.5449
# 2024-04-04 05:46:05.458436: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.23722, expected 5.482
# 2024-04-04 05:46:05.458448: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.08366, expected 5.32844
# 2024-04-04 05:46:05.458460: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.04657, expected 5.29135
# 2024-04-04 05:46:05.458471: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.75857, expected 5.00335
# 2024-04-04 05:46:05.458482: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.00133, expected 4.24611
# 2024-04-04 05:46:05.458492: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.91496, expected 4.15974
# 2024-04-04 05:46:05.458502: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.14032, expected 4.3851
# 2024-04-04 05:46:05.469365: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 05:46:05.469408: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 05:46:05.469425: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 05:46:05.469433: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 05:46:05.469440: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 05:46:05.469456: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-04-04 05:46:05.836806: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.14422, expected 3.389
# 2024-04-04 05:46:05.836864: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.90007, expected 5.14485
# 2024-04-04 05:46:05.836874: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.30012, expected 5.5449
# 2024-04-04 05:46:05.836882: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.23722, expected 5.482
# 2024-04-04 05:46:05.836890: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.08366, expected 5.32844
# 2024-04-04 05:46:05.836897: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.04657, expected 5.29135
# 2024-04-04 05:46:05.836905: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.75857, expected 5.00335
# 2024-04-04 05:46:05.836913: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.00133, expected 4.24611
# 2024-04-04 05:46:05.836921: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.91496, expected 4.15974
# 2024-04-04 05:46:05.836928: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.14032, expected 4.3851
# 2024-04-04 05:46:05.847484: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,8,299,299]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,299,299]{3,2,1,0}, f32[8,3,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-04-04 05:46:05.847522: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-04-04 05:46:05.847531: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-04-04 05:46:05.847538: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-04-04 05:46:05.847546: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-04-04 05:46:05.847561: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 109ms/step
